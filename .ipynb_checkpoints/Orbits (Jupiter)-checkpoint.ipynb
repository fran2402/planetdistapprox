# %%
import numpy as np
import matplotlib.pyplot as plt
from skyfield.api import load
from scipy.optimize import curve_fit
from matplotlib.pyplot import figure, show, subplots, tight_layout


data   = load('de421.bsp')
ts     = load.timescale()
t      = ts.utc(2023, 1, range(366 * 30))

print(t)

jupiter, earth  = data['Jupiter barycenter'], data['Earth']
jpos, epos      = jupiter.at(t).position.au, earth.at(t).position.au
dis = (((jpos[0]-epos[0])**2+(jpos[1]-epos[1])**2+(jpos[2]-epos[2])**2)**0.5)


plt.plot(t.J-2023, dis, "bo", ms= 1)
plt.show()
# Out:
# <Time tt=[2459944.500800741 ... 2470923.500800741] len=10980>

# %%
b = 5.70551
def fit(x, a, c, d, e, f):
    res = a*(np.sin(b/12.009*x+f)+e*np.sin(b*x+d))+c
    return res

a = 5
c = 5.3
d = 1
e = 5
f = 1



p0 = (a, c, d, e, f)

popt, pcov = curve_fit(fit, t.J-2023, dis, p0=p0)

print(popt)

fig = figure()
fig.set_size_inches(8, 8)
frame = fig.add_subplot(1,1,1)
frame.plot(t.J-2023, dis, "b")
frame.plot(t.J-2023, fit(t.J, *popt), "r-")
fig.set_size_inches(10, 5)
show()
# Out:
# [0.22854311 5.26117944 0.67555447 3.96298089 5.59713961]

# %%
a = -0.23325678
b = 5.7055
c = 5.23327476
d = -0.04369186
e = -4.25639507
f = 1.75948047

x1 = np.linspace(0,np.max(t.J-2023),len(t))
y1 = [a*(np.sin(b/12.009*x1+f)+e*np.sin(b*x1+d))+c for x1 in x1]


fig = figure()
fig.set_size_inches(8, 8)
frame = fig.add_subplot(1,1,1)
frame.plot(t.J-2023, dis, "b")
frame.plot(t.J-2023, y1, "r")
fig.set_size_inches(10, 5)
show()

# %%
from scipy.fft import fft, fftfreq

import numpy as np

# Number of sample points

N = 600

# sample spacing

T = 1.0 / 800.0

x = t.J-2000

y = dis

yf = fft(y)

xf = fftfreq(N, T)[:N//2]

import matplotlib.pyplot as plt

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))

plt.grid()

plt.show()

# %%
print((2.0/N * np.abs(yf[0:N//2])))
print(xf[18])
# Out:
# [1.29342680e+02 1.58702723e+00 2.28114034e+00 3.17938334e-01
#  2.25852064e-01 1.92890986e-01 2.12608617e-01 2.40342059e-01
#  2.74073304e-01 3.13866603e-01 3.62336444e-01 4.23457888e-01
#  5.03519206e-01 6.13918791e-01 7.77484782e-01 1.02810160e+00
#  1.61586706e+00 2.07262326e+00 9.62329820e+00 5.44358933e+00
#  2.71073011e+00 1.36797080e+00 1.02035121e+00 8.14762629e-01
#  6.81942837e-01 5.88846697e-01 5.19980237e-01 4.67119971e-01
#  4.25398322e-01 3.91848041e-01 3.64584843e-01 3.42298571e-01
#  3.24997046e-01 3.09262699e-01 3.10911377e-01 2.52753584e-01
#  4.20471309e-01 3.46139045e-01 8.26409746e-02 2.18634701e-01
#  1.95244486e-01 1.82496233e-01 1.77022125e-01 1.71847173e-01
#  1.67067086e-01 1.62411939e-01 1.57994058e-01 1.53812481e-01
#  2.98022180e-02 2.96576040e-02 2.95147702e-02 2.93729860e-02
#  2.92325410e-02 2.90935881e-02 2.89558611e-02 2.88194922e-02
#  2.86844056e-02 2.85506099e-02 2.84180560e-02 2.82867393e-02
#  2.81566404e-02 2.80277439e-02 2.79000302e-02 2.77734935e-02
#  2.76480784e-02 2.75238030e-02 2.74006262e-02 2.72785227e-02
#  2.71568259e-02 2.70356556e-02 2.69222538e-02 2.68024618e-02
#  2.66857693e-02 2.65698902e-02 2.64551711e-02 2.63414555e-02
#  2.62287703e-02 2.61170618e-02 2.60063056e-02 2.58965172e-02
#  2.57876722e-02 2.56797580e-02 2.55727748e-02 2.54667294e-02
#  2.53616094e-02 2.52575560e-02 2.51539065e-02 2.50548006e-02
#  2.49153254e-02 2.48438691e-02 2.47445434e-02 2.46459839e-02
#  2.45476753e-02 2.44499854e-02 2.43530274e-02 2.42567259e-02
#  2.41611468e-02 2.40662516e-02 2.39720074e-02 2.38783758e-02
#  2.37852954e-02 2.36926782e-02 2.36000752e-02 2.35082044e-02
#  2.34095443e-02 2.33303412e-02 2.31606305e-02 2.31931716e-02
#  2.30838407e-02 2.29978028e-02 2.29099541e-02 2.28242767e-02
#  2.27380172e-02 2.26542217e-02 2.25706454e-02 2.24878101e-02
#  2.24056233e-02 2.23240634e-02 2.22430941e-02 2.21626882e-02
#  2.20828527e-02 2.20032795e-02 2.19243711e-02 2.18452057e-02
#  2.17607262e-02 2.17107729e-02 2.16255951e-02 2.15447700e-02
#  2.14693812e-02 2.13944851e-02 2.13202203e-02 2.12465951e-02
#  2.11734591e-02 2.11008669e-02 2.10287895e-02 2.09572242e-02
#  2.08861593e-02 2.08155977e-02 2.07455062e-02 2.06758749e-02]
# 24.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from skyfield.api import load
from scipy.optimize import curve_fit
from matplotlib.pyplot import figure, show, subplots, tight_layout


data   = load('de421.bsp')
ts     = load.timescale()
t      = ts.utc(2023, 1, range(366 * 30))

print(t)

jupiter, earth  = data['Neptune barycenter'], data['Earth']
jpos, epos      = jupiter.at(t).position.au, earth.at(t).position.au
dis = (((jpos[0]-epos[0])**2+(jpos[1]-epos[1])**2+(jpos[2]-epos[2])**2)**0.5)


plt.plot(t.J-2023, dis, "bo", ms= 1)
plt.show()
# Out:
# <Time tt=[2459944.500800741 ... 2470923.500800741] len=10980>

# %%
b = 1500
def fit(x, a, c, d, e, f):
    res = a*(np.sin(b/165*x+f)+e*np.sin(b*x+d))+c
    return res

a = 5
c = 25
d = 1
e = 5
f = 1



p0 = (a, c, d, e, f)

popt, pcov = curve_fit(fit, t.J-2023, dis, p0=p0)

print(popt)

fig = figure()
fig.set_size_inches(8, 8)
frame = fig.add_subplot(1,1,1)
frame.plot(t.J-2023, dis, "b")
frame.plot(t.J-2023, fit(t.J, *popt), "r-")
fig.set_size_inches(10, 5)
show()
# Out:
# [-1.76651925e-02  2.98513803e+01 -1.01489580e+00 -1.28448009e-03
#   1.43716059e+00]
